# %% [markdown]
# <a href="https://colab.research.google.com/github/saraibare/1.-Extracci-n-de-datos/blob/main/Act_1_1_Filtros.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
#Importamos librerías requeridas
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
from google.colab import files

# %%
#Cargar archivo csv desde equipo
from google.colab import files
uploaded=files.upload()
# Out:
#      <input type="file" id="files-d3520f9b-da1f-45ec-830b-07562bfc7c72" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-d3520f9b-da1f-45ec-830b-07562bfc7c72">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %%
#Convertir en dataframe
df= pd.read_csv("Detalle precios y productos fabricados 2022.csv")
df.head()
# Out:
#   CVE_DOC        FECHA_DOC                     NOMBRE  \
# 0  F37034  05/01/2022 0:00  LETICIA RAMIREZ HERNANDEZ
# 1  F37036  05/01/2022 0:00  LETICIA RAMIREZ HERNANDEZ
# 2  F37041  05/01/2022 0:00   DIEGO ARMANDO LEON DURAN
# 3  F37042  05/01/2022 0:00   DIEGO ARMANDO LEON DURAN
# 4  F37043  05/01/2022 0:00  LETICIA RAMIREZ HERNANDEZ
#
#                        NOMBRE.1  CANT   CVE_ART  \
# 0            PÚBLICO EN GENERAL     1  TUE00244
# 1  JUAN ANTONIO RESENDIZ UGALDE     1  TUA00028
# 2     ANA BARBARA CRUZ PALACIOS     7    TP0007
# 3          OMAR RODRIGUEZ GOMEZ     1    TP0001
# 4            PÚBLICO EN GENERAL     2   BP00242
#
#                                      DESCR  PRECIO_UNITARIO  COSTO_UNITARIO  \
# 0  TUB COBRE 5/16"ØX165MM CIRCULA1.5KW127V           434.48           52.80
# 1  TUA U" 5/16 ØX250MM 1200W 120V TAP1"NPT          1264.05          327.18
# 2     TERMOPAR J 3/16 Ø X 1' 1/2 EXT. 7 MT           551.61          177.68
# ...

# %%
#Verificamos información del DataFrame
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1426 entries, 0 to 1425
# Data columns (total 14 columns):
#  #   Column                     Non-Null Count  Dtype
# ---  ------                     --------------  -----
#  0   CVE_DOC                    1426 non-null   object
#  1   FECHA_DOC                  1426 non-null   object
#  2   NOMBRE                     1424 non-null   object
#  3   NOMBRE.1                   1426 non-null   object
#  4   CANT                       1426 non-null   int64
#  5   CVE_ART                    1426 non-null   object
#  6   DESCR                      1426 non-null   object
#  7   PRECIO_UNITARIO            1426 non-null   float64
#  8   COSTO_UNITARIO             1426 non-null   float64
#  9   COSTO_UNITARIO_CALCULADO   1426 non-null   float64
#  10  SUBTOTAL_PARTIDA           1426 non-null   float64
#  11  COSTO_TOTAL_CALCULADO      1426 non-null   float64
#  12  MARGEN_UNITARIO_CALCULADO  1426 non-null   float64
# ...

# %% [markdown]
# ## **1. Filtro por objeto**

# %%
filtro1=df[df["NOMBRE.1"] == "PROVEEDORA DE SEGURIDAD INDUSTRIAL DEL GOLFO"]
filtro1.head()
# Out:
#     CVE_DOC        FECHA_DOC          NOMBRE  \
# 74   F37169  21/01/2022 0:00  ALFREDO CANELA
# 150  F37331  10/02/2022 0:00  ALFREDO CANELA
# 245  F37493  28/02/2022 0:00  ALFREDO CANELA
# 327  F37658  16/03/2022 0:00  ALFREDO CANELA
# 410  F37803  31/03/2022 0:00  ALFREDO CANELA
#
#                                          NOMBRE.1  CANT    CVE_ART  \
# 74   PROVEEDORA DE SEGURIDAD INDUSTRIAL DEL GOLFO    30  ECQ-00972
# 150  PROVEEDORA DE SEGURIDAD INDUSTRIAL DEL GOLFO     3  ECQ-01444
# 245  PROVEEDORA DE SEGURIDAD INDUSTRIAL DEL GOLFO    30  ECQ-00972
# 327  PROVEEDORA DE SEGURIDAD INDUSTRIAL DEL GOLFO     2  ECQ-01444
# 410  PROVEEDORA DE SEGURIDAD INDUSTRIAL DEL GOLFO    25  ECQ-00972
#
#                                         DESCR  PRECIO_UNITARIO  \
# 74   TUB. ENCAPSULADA 5/16Øx780mm 1500W 240V"          1475.30
# 150    TUBULAR  U" 1/2"Øx660mm 4500W440V 3pz"          3053.25
# 245  TUB. ENCAPSULADA 5/16Øx780mm 1500W 240V"          1475.30
# ...

# %% [markdown]
# Se muestran solo las compras hechas por la Proveedora de Seguridad Industrial del Golfo. (se utiliza la columna "Nombre.1"

# %%
filtro1.to_csv("Filtro1.csv")
files.download("Filtro1.csv")

# %% [markdown]
# ## **2. Filtro por filas**

# %%
filtro2= df.iloc[11:21,: ]
filtro2
# Out:
#    CVE_DOC        FECHA_DOC                    NOMBRE  \
# 11  F37051  05/01/2022 0:00  DIEGO ARMANDO LEON DURAN
# 12  F37052  05/01/2022 0:00  DIEGO ARMANDO LEON DURAN
# 13  F37053  05/01/2022 0:00  DIEGO ARMANDO LEON DURAN
# 14  F37054  05/01/2022 0:00  DIEGO ARMANDO LEON DURAN
# 15  F37058  05/01/2022 0:00  DIEGO ARMANDO LEON DURAN
# 16  F37059  05/01/2022 0:00  DIEGO ARMANDO LEON DURAN
# 17  F37060  05/01/2022 0:00  DIEGO ARMANDO LEON DURAN
# 18  F37061  05/01/2022 0:00            ALFREDO CANELA
# 19  F37061  05/01/2022 0:00            ALFREDO CANELA
# 20  F37061  05/01/2022 0:00            ALFREDO CANELA
#
#                      NOMBRE.1  CANT       CVE_ART  \
# 11         FIDEICOMISO F/1596     1      TUE00207
# 12         FIDEICOMISO F/1596     1      TUE00207
# 13  SANDIBEEL BECERRA HURTADO     1       BO00051
# 14            INDUSTRIAS NIBA     1       BC00023
# 15         MOLINERA DE MEXICO     5       PT00070
# 16   SILCA CERAMICO PRODUCTOS     2        TP0011
# ...

# %% [markdown]
# Se filtraron las siguientes 10 filas consecutivas, es decir, de la 11 hasta la 20.

# %%
filtro2.to_csv("Filtro2.csv")
files.download("Filtro2.csv")

# %% [markdown]
# ## **3. Filtro por columnas**

# %%
filtro3=df.iloc[ : , [1,3,11,13]] 
filtro3
# Out:
#             FECHA_DOC                      NOMBRE.1  COSTO_TOTAL_CALCULADO  \
# 0     05/01/2022 0:00            PÚBLICO EN GENERAL                  52.80
# 1     05/01/2022 0:00  JUAN ANTONIO RESENDIZ UGALDE                 327.18
# 2     05/01/2022 0:00     ANA BARBARA CRUZ PALACIOS                1243.73
# 3     05/01/2022 0:00          OMAR RODRIGUEZ GOMEZ                  38.96
# 4     05/01/2022 0:00            PÚBLICO EN GENERAL                 203.42
# ...               ...                           ...                    ...
# 1421  23/12/2022 0:00     LUIS ENRIQUE PATIÑO PEREZ                 613.88
# 1422  23/12/2022 0:00     LUIS ENRIQUE PATIÑO PEREZ                 628.12
# 1423  23/12/2022 0:00          SEVEN DAYS ALL SPORT                1789.64
# 1424  23/12/2022 0:00           REVUELTA MONTECARLO                1884.35
# 1425  23/12/2022 0:00                CPEG SOLUTIONS                 806.55
#
#       MARGEN_TOTAL_CALCULADO
# 0                     381.68
# ...

# %% [markdown]
# Muestra solo el costo y margen total de cada factura, junto con el nombre del cliente y la fecha en la que se realizó la compra.

# %%
filtro3.to_csv("Filtro3.csv")
files.download("Filtro3.csv")

# %% [markdown]
# ## **4. Filtro de filas vs columnas**

# %%
df1= pd.read_csv("Detalle precios y productos fabricados 2022.csv", index_col=0)
filtro4=df1.loc[["F37042","F37255","F38887"], ["SUBTOTAL_PARTIDA"]]
filtro4
# Out:
#          SUBTOTAL_PARTIDA
# CVE_DOC
# F37042              140.0
# F37255             1000.0
# F38887              813.0

# %% [markdown]
# Muestra el total de las facturas "F37042","F37255" y "F38887".

# %%
filtro4.to_csv("Filtro4.csv")
files.download("Filtro4.csv")

# %% [markdown]
# ## **5. Filtro por cabecera**

# %%
filtro5=df.head(50)
filtro5
# Out:
#    CVE_DOC        FECHA_DOC                     NOMBRE  \
# 0   F37034  05/01/2022 0:00  LETICIA RAMIREZ HERNANDEZ
# 1   F37036  05/01/2022 0:00  LETICIA RAMIREZ HERNANDEZ
# 2   F37041  05/01/2022 0:00   DIEGO ARMANDO LEON DURAN
# 3   F37042  05/01/2022 0:00   DIEGO ARMANDO LEON DURAN
# 4   F37043  05/01/2022 0:00  LETICIA RAMIREZ HERNANDEZ
# 5   F37043  05/01/2022 0:00  LETICIA RAMIREZ HERNANDEZ
# 6   F37044  05/01/2022 0:00   DIEGO ARMANDO LEON DURAN
# 7   F37046  05/01/2022 0:00  LETICIA RAMIREZ HERNANDEZ
# 8   F37048  05/01/2022 0:00   DIEGO ARMANDO LEON DURAN
# 9   F37049  05/01/2022 0:00   DIEGO ARMANDO LEON DURAN
# 10  F37050  05/01/2022 0:00   DIEGO ARMANDO LEON DURAN
# 11  F37051  05/01/2022 0:00   DIEGO ARMANDO LEON DURAN
# 12  F37052  05/01/2022 0:00   DIEGO ARMANDO LEON DURAN
# 13  F37053  05/01/2022 0:00   DIEGO ARMANDO LEON DURAN
# 14  F37054  05/01/2022 0:00   DIEGO ARMANDO LEON DURAN
# 15  F37058  05/01/2022 0:00   DIEGO ARMANDO LEON DURAN
# ...

# %% [markdown]
# Se filtraron los primeros 50 registros de facturas.

# %%
filtro5.to_csv("Filtro5.csv")
files.download("Filtro5.csv")

# %% [markdown]
# ## **6. Filtro por comparación**

# %%
filtro6=df[df["MARGEN_TOTAL_CALCULADO"] > df["MARGEN_TOTAL_CALCULADO"].mean()]
filtro6
# Out:
#      CVE_DOC        FECHA_DOC                     NOMBRE  \
# 6     F37044  05/01/2022 0:00   DIEGO ARMANDO LEON DURAN
# 18    F37061  05/01/2022 0:00             ALFREDO CANELA
# 19    F37061  05/01/2022 0:00             ALFREDO CANELA
# 29    F37078  07/01/2022 0:00             ALFREDO CANELA
# 31    F37086  10/01/2022 0:00             ALFREDO CANELA
# ...      ...              ...                        ...
# 1421  F39834  23/12/2022 0:00  LETICIA RAMIREZ HERNANDEZ
# 1422  F39834  23/12/2022 0:00  LETICIA RAMIREZ HERNANDEZ
# 1423  F39835  23/12/2022 0:00  LETICIA RAMIREZ HERNANDEZ
# 1424  F39837  23/12/2022 0:00  LETICIA RAMIREZ HERNANDEZ
# 1425  F39838  23/12/2022 0:00         AARON NUÑO CORDOVA
#
#                                  NOMBRE.1  CANT       CVE_ART  \
# 6     AIRBUS HELICOPTERS MEXICO QUERETARO     1       RP00165
# 18                               ELICAMEX     5      WRE-2133
# 19                               ELICAMEX     7      WRE-2774
# ...

# %% [markdown]
# Filtro las facturas que tienen un margen de ganancia mayor al margen promedio de las facturas, utilizando la columna "MARGEN_TOTAL_CALCULADO".

# %%
filtro6.to_csv("Filtro6.csv")
files.download("Filtro6.csv")

# %% [markdown]
# ## **7. Filtro and**

# %%
filtro7=df[(df["CVE_ART"] == "TP0011") & (df["SUBTOTAL_PARTIDA"] > 1000)]
filtro7
# Out:
#      CVE_DOC        FECHA_DOC                     NOMBRE  \
# 16    F37059  05/01/2022 0:00   DIEGO ARMANDO LEON DURAN
# 26    F37073  07/01/2022 0:00  LETICIA RAMIREZ HERNANDEZ
# 301   F37605  10/03/2022 0:00  LETICIA RAMIREZ HERNANDEZ
# 543   F38067  04/05/2022 0:00  LETICIA RAMIREZ HERNANDEZ
# 576   F38132  11/05/2022 0:00  LETICIA RAMIREZ HERNANDEZ
# 669   F38349  09/06/2022 0:00  LETICIA RAMIREZ HERNANDEZ
# 711   F38427  21/06/2022 0:00  LETICIA RAMIREZ HERNANDEZ
# 760   F38501  30/06/2022 0:00  LETICIA RAMIREZ HERNANDEZ
# 803   F38586  13/07/2022 0:00  LETICIA RAMIREZ HERNANDEZ
# 877   F38727  01/08/2022 0:00  LETICIA RAMIREZ HERNANDEZ
# 886   F38760  08/08/2022 0:00        ATENCION A CLIENTES
# 1115  F39233  04/10/2022 0:00  LETICIA RAMIREZ HERNANDEZ
# 1134  F39274  10/10/2022 0:00  LETICIA RAMIREZ HERNANDEZ
# 1310  F39610  22/11/2022 0:00  LETICIA RAMIREZ HERNANDEZ
#
#                            NOMBRE.1  CANT CVE_ART  \
# 16         SILCA CERAMICO PRODUCTOS     2  TP0011
# ...

# %% [markdown]
# Se muestran solo las facturas cuyo artículo sea el correspondiente a la clave "TP0011" y que el total de la factura supere los mil pesos, utilizando las columnas "CVE_ART" y "SUBTOTAL_PARTIDA".

# %%
filtro7.to_csv("Filtro7.csv")
files.download("Filtro7.csv")

# %% [markdown]
# ## **8. Filtro or**

# %%
#Filtro o
filtro8=df[(df["NOMBRE"] == "LETICIA RAMIREZ HERNANDEZ") | (df["NOMBRE.1"] == "CARCOUSTICS INDUSTRIAL DE MEXICO")]
filtro8
# Out:
#      CVE_DOC        FECHA_DOC                     NOMBRE  \
# 0     F37034  05/01/2022 0:00  LETICIA RAMIREZ HERNANDEZ
# 1     F37036  05/01/2022 0:00  LETICIA RAMIREZ HERNANDEZ
# 4     F37043  05/01/2022 0:00  LETICIA RAMIREZ HERNANDEZ
# 5     F37043  05/01/2022 0:00  LETICIA RAMIREZ HERNANDEZ
# 7     F37046  05/01/2022 0:00  LETICIA RAMIREZ HERNANDEZ
# ...      ...              ...                        ...
# 1416  F39830  23/12/2022 0:00  LETICIA RAMIREZ HERNANDEZ
# 1421  F39834  23/12/2022 0:00  LETICIA RAMIREZ HERNANDEZ
# 1422  F39834  23/12/2022 0:00  LETICIA RAMIREZ HERNANDEZ
# 1423  F39835  23/12/2022 0:00  LETICIA RAMIREZ HERNANDEZ
# 1424  F39837  23/12/2022 0:00  LETICIA RAMIREZ HERNANDEZ
#
#                           NOMBRE.1  CANT       CVE_ART  \
# 0               PÚBLICO EN GENERAL     1      TUE00244
# 1     JUAN ANTONIO RESENDIZ UGALDE     1      TUA00028
# 4               PÚBLICO EN GENERAL     2       BP00242
# ...

# %% [markdown]
# Se muestra las ventas hechas por Leticia Ramírez o las compras hechas por la empresa Carcoustics Industrial, utilizando las columnas nombre y nombre.1 respectivamente.

# %%
filtro8.to_csv("Filtro8.csv")
files.download("Filtro8.csv")

# %% [markdown]
# ## **9. Filtro not**

# %%
filtro9=df[~(df["NOMBRE"] == "DIEGO ARMANDO LEON DURAN") & ~(df["NOMBRE.1"] == "FIDEICOMISO F/1596")]
filtro9
# Out:
#      CVE_DOC        FECHA_DOC                     NOMBRE  \
# 0     F37034  05/01/2022 0:00  LETICIA RAMIREZ HERNANDEZ
# 1     F37036  05/01/2022 0:00  LETICIA RAMIREZ HERNANDEZ
# 4     F37043  05/01/2022 0:00  LETICIA RAMIREZ HERNANDEZ
# 5     F37043  05/01/2022 0:00  LETICIA RAMIREZ HERNANDEZ
# 7     F37046  05/01/2022 0:00  LETICIA RAMIREZ HERNANDEZ
# ...      ...              ...                        ...
# 1421  F39834  23/12/2022 0:00  LETICIA RAMIREZ HERNANDEZ
# 1422  F39834  23/12/2022 0:00  LETICIA RAMIREZ HERNANDEZ
# 1423  F39835  23/12/2022 0:00  LETICIA RAMIREZ HERNANDEZ
# 1424  F39837  23/12/2022 0:00  LETICIA RAMIREZ HERNANDEZ
# 1425  F39838  23/12/2022 0:00         AARON NUÑO CORDOVA
#
#                           NOMBRE.1  CANT       CVE_ART  \
# 0               PÚBLICO EN GENERAL     1      TUE00244
# 1     JUAN ANTONIO RESENDIZ UGALDE     1      TUA00028
# 4               PÚBLICO EN GENERAL     2       BP00242
# ...

# %% [markdown]
# Se filtraron todas las facturas que no tuvieran como vendedor a Diego Armando o como comprador a "FIDEICOMISO F/1596", utilizando las columnas Nombre y Nombre.1 respectivamente.

# %%
filtro9.to_csv("Filtro9.csv")
files.download("Filtro9.csv")
